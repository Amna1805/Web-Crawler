# %%
import os
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
import uuid
import re

class WebCrawler:
    def __init__(self):
        self.visited_urls = set()
        self.pages_crawled = 0
        self.output_folder = "crawled_pages"

        if not os.path.exists(self.output_folder):
            os.makedirs(self.output_folder)

    def crawl(self, seed_url, max_pages=1000):
        self._crawl_page(seed_url, max_pages)

    
    def _crawl_page(self, url, max_pages):
        if self.pages_crawled >= max_pages:
            return
    
        if url in self.visited_urls:
            return
        self.visited_urls.add(url)
    
        try:
            response = requests.get(url)
            if response.status_code == 200:
                soup = BeautifulSoup(response.text, "html.parser")
                self._save_page(url, soup)
                self.pages_crawled += 1
                print(f"Crawled {url}. Number of Pages crawled: {self.pages_crawled}")
                for link in soup.find_all("a", href=True):
                    absolute_url = urljoin(url, link["href"])
                    self._crawl_page(absolute_url, max_pages)
        except Exception as e:
            print(f"Error crawling {url}: {e}")
            # Continue crawling other pages even if an error occurs
            for link in soup.find_all("a", href=True):
                absolute_url = urljoin(url, link["href"])
                self._crawl_page(absolute_url, max_pages)


    def _save_page(self, url, soup):
        if not self._is_page_english(soup):
            return
    
        unique_id = str(uuid.uuid4())
    
        title = soup.title.string.strip() if soup.title else ""
        
        # Extract headings
        headings = [heading.text.strip() for heading in soup.find_all(["h1", "h2", "h3", "h4", "h5", "h6"])]
    
        # Extract a portion of the page body (e.g., first three paragraphs)
        page_body = ""
        for paragraph in soup.find_all("p")[:3]:  # Extract first three paragraphs
            page_body += paragraph.get_text().strip() + "\n"
    
        # Save page
        filename = f"page{self.pages_crawled + 1}.txt"  # Modify filename format
        filepath = os.path.join(self.output_folder, filename)
        with open(filepath, "w", encoding="utf-8") as f:
            f.write(f"URL: {url}\n")
            f.write(f"Title: {title}\n")
            f.write(f"Headings:\n")
            for heading in headings:
                f.write(f"- {heading}\n")
            f.write(f"\nPage Body:\n{page_body}")

    def _is_page_english(self, soup):
        lang_attr = soup.html.get("lang")
        if lang_attr and lang_attr.startswith("en"):
            return True
        return False

# %%
if __name__ == "__main__":
    # Create a WebCrawler instance
    crawler = WebCrawler()
    
    # Define the seed URL
    seed_url = "https://en.wikipedia.org/wiki/Plant"
    
    # Specify the maximum number of pages to crawl
    max_pages = 1000
    
    # Start crawling
    crawler.crawl(seed_url, max_pages)
    
    # Print the root directory for crawled pages
    print("Root directory for crawled pages:", os.path.abspath(crawler.output_folder))
# Out:
# Crawled https://en.wikipedia.org/wiki/Plant. Number of Pages crawled: 1
# Crawled https://en.wikipedia.org/wiki/Plant#bodyContent. Number of Pages crawled: 2
# Crawled https://en.wikipedia.org/wiki/Main_Page. Number of Pages crawled: 3
# Crawled https://en.wikipedia.org/wiki/Main_Page#bodyContent. Number of Pages crawled: 4
# Crawled https://en.wikipedia.org/wiki/Wikipedia:Contents. Number of Pages crawled: 5
# Crawled https://en.wikipedia.org/wiki/Wikipedia:Contents#bodyContent. Number of Pages crawled: 6
# Crawled https://en.wikipedia.org/wiki/Portal:Current_events. Number of Pages crawled: 7
# Crawled https://en.wikipedia.org/wiki/Portal:Current_events#bodyContent. Number of Pages crawled: 8
# Crawled https://en.wikipedia.org/wiki/Special:Random. Number of Pages crawled: 9
# Crawled https://en.wikipedia.org/wiki/Special:Random#bodyContent. Number of Pages crawled: 10
# Crawled https://en.wikipedia.org/wiki/Wikipedia:About. Number of Pages crawled: 11
# Crawled https://en.wikipedia.org/wiki/Wikipedia:About#bodyContent. Number of Pages crawled: 12
# Crawled https://en.wikipedia.org/wiki/Wikipedia:Contact_us. Number of Pages crawled: 13
# Crawled https://en.wikipedia.org/wiki/Wikipedia:Contact_us#bodyContent. Number of Pages crawled: 14
# Crawled https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en. Number of Pages crawled: 15
# Crawled https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en#mw-head. Number of Pages crawled: 16
# Crawled https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en#searchInput. Number of Pages crawled: 17
# Crawled https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=Tax_deductibility&basic=true&language=en. Number of Pages crawled: 18
# Crawled https://donate.wikimedia.org/w/index.php?title=Tax_deductibility/en&redirect=no. Number of Pages crawled: 19
# Crawled https://donate.wikimedia.org/w/index.php?title=Tax_deductibility/en&redirect=no#mw-head. Number of Pages crawled: 20
# Crawled https://donate.wikimedia.org/w/index.php?title=Tax_deductibility/en&redirect=no#searchInput. Number of Pages crawled: 21
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility. Number of Pages crawled: 22
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility#mw-head. Number of Pages crawled: 23
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility#searchInput. Number of Pages crawled: 24
# Crawled https://wikimediafoundation.org/. Number of Pages crawled: 25
# Crawled https://wikimediafoundation.org/#content. Number of Pages crawled: 26
# Crawled https://wikimediafoundation.org. Number of Pages crawled: 27
# Crawled https://wikimediafoundation.org#content. Number of Pages crawled: 28
# Crawled https://wikimediafoundation.org/ar/. Number of Pages crawled: 29
# Crawled https://wikimediafoundation.org/ar/#content. Number of Pages crawled: 30
# Crawled https://wikimediafoundation.org/ar. Number of Pages crawled: 31
# Crawled https://wikimediafoundation.org/ar#content. Number of Pages crawled: 32
# Crawled https://wikimediafoundation.org/zh/. Number of Pages crawled: 33
# Crawled https://wikimediafoundation.org/zh/#content. Number of Pages crawled: 34
# Crawled https://wikimediafoundation.org/zh. Number of Pages crawled: 35
# Crawled https://wikimediafoundation.org/zh#content. Number of Pages crawled: 36
# Crawled https://wikimediafoundation.org/fr/. Number of Pages crawled: 37
# Crawled https://wikimediafoundation.org/fr/#content. Number of Pages crawled: 38
# Crawled https://wikimediafoundation.org/fr. Number of Pages crawled: 39
# Crawled https://wikimediafoundation.org/fr#content. Number of Pages crawled: 40
# Crawled https://wikimediafoundation.org/ru/. Number of Pages crawled: 41
# Crawled https://wikimediafoundation.org/ru/#content. Number of Pages crawled: 42
# Crawled https://wikimediafoundation.org/ru. Number of Pages crawled: 43
# Crawled https://wikimediafoundation.org/ru#content. Number of Pages crawled: 44
# Crawled https://wikimediafoundation.org/es/. Number of Pages crawled: 45
# Crawled https://wikimediafoundation.org/es/#content. Number of Pages crawled: 46
# Crawled https://wikimediafoundation.org/es. Number of Pages crawled: 47
# Crawled https://wikimediafoundation.org/es#content. Number of Pages crawled: 48
# Crawled https://wikimediafoundation.org/de/. Number of Pages crawled: 49
# Crawled https://wikimediafoundation.org/de/#content. Number of Pages crawled: 50
# Crawled https://wikimediafoundation.org/de. Number of Pages crawled: 51
# Crawled https://wikimediafoundation.org/de#content. Number of Pages crawled: 52
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=comms&uselang=de&utm_source=10. Number of Pages crawled: 53
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=comms&uselang=de&utm_source
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility/uk#searchInput. Number of Pages crawled: 127
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility/zu. Number of Pages crawled: 128
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility/zu#mw-head. Number of Pages crawled: 129
# Crawled https://donate.wikimedia.org/wiki/Tax_deductibility/zu#searchInput. Number of Pages crawled: 130
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Tax_deductibility. Number of Pages crawled: 131
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Tax_deductibility#mw-head. Number of Pages crawled: 132
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Tax_deductibility#searchInput. Number of Pages crawled: 133
# Crawled https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=en. Number of Pages crawled: 134
# Crawled https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=en#bodyContent. Number of Pages crawled: 135
# Crawled https://foundation.wikimedia.org/wiki/Special:MyLanguage/Home. Number of Pages crawled: 136
# Crawled https://foundation.wikimedia.org/wiki/Special:MyLanguage/Home#bodyContent. Number of Pages crawled: 137
# Crawled https://wikimediafoundation.org/about/contact/. Number of Pages crawled: 138
# Crawled https://wikimediafoundation.org/about/contact/#content. Number of Pages crawled: 139
# Crawled https://wikimediafoundation.org/ar/about/contact/. Number of Pages crawled: 140
# Crawled https://wikimediafoundation.org/ar/about/contact/#content. Number of Pages crawled: 141
# Crawled https://wikimediafoundation.org/zh/about/contact/. Number of Pages crawled: 142
# Crawled https://wikimediafoundation.org/zh/about/contact/#content. Number of Pages crawled: 143
# Crawled https://wikimediafoundation.org/fr/about/contact/. Number of Pages crawled: 144
# Crawled https://wikimediafoundation.org/fr/about/contact/#content. Number of Pages crawled: 145
# Crawled https://wikimediafoundation.org/ru/about/contact/. Number of Pages crawled: 146
# Crawled https://wikimediafoundation.org/ru/about/contact/#content. Number of Pages crawled: 147
# Crawled https://wikimediafoundation.org/es/about/contact/. Number of Pages crawled: 148
# Crawled https://wikimediafoundation.org/es/about/contact/#content. Number of Pages crawled: 149
# Crawled https://wikimediafoundation.org/de/about/contact/. Number of Pages crawled: 150
# Crawled https://wikimediafoundation.org/de/about/contact/#content. Number of Pages crawled: 151
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=comms&uselang=de&utm_source=154. Number of Pages crawled: 152
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=comms&uselang=de&utm_source=154#mw-head. Number of Pages crawled: 153
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=comms&uselang=de&utm_source=154#searchInput. Number of Pages crawled: 154
# Crawled https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=de. Number of Pages crawled: 155
# Crawled https://foundation.wikimedia.org/wiki/Special:LandingCheck?landing_page=Donor_privacy_policy&basic=true&language=de#bodyContent. Number of Pages crawled: 156
# Crawled https://wikimediafoundation.org/news/. Number of Pages crawled: 157
# Crawled https://wikimediafoundation.org/news/#content. Number of Pages crawled: 158
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=navButton&uselang=en&utm_source=11. Number of Pages crawled: 159
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=navButton&uselang=en&utm_source=11#mw-head. Number of Pages crawled: 160
# Crawled https://donate.wikimedia.org/?utm_medium=wmfSite&utm_campaign=navButton&uselang=en&utm_source=11#searchInput. Number of Pages crawled: 161
# Crawled https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=Problems_donating&basic=true&language=en. Number of Pages crawled: 162
# Crawled https://donate.wikimedia.org/w/index.php?title=Problems_donating/en&redirect=no. Number of Pages crawled: 163
# Crawled https://donate.wikimedia.org/w/index.php?title=Problems_donating/en&redirect=no#mw-head. Number of Pages crawled: 164
# Crawled https://donate.wikimedia.org/w/index.php?title=Problems_donating/en&redirect=no#searchInput. Number of Pages crawled: 165
# Crawled https://donate.wikimedia.org/wiki/Problems_donating. Number of Pages crawled: 166
# Crawled https://donate.wikimedia.org/wiki/Problems_donating#mw-head. Number of Pages crawled: 167
# Crawled https://donate.wikimedia.org/wiki/Problems_donating#searchInput. Number of Pages crawled: 168
# Crawled https://donate.wikimedia.org/wiki/Problems_donating
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/ro#mw-head. Number of Pages crawled: 309
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/ro#searchInput. Number of Pages crawled: 310
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/ru. Number of Pages crawled: 311
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/ru#mw-head. Number of Pages crawled: 312
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/ru#searchInput. Number of Pages crawled: 313
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sk. Number of Pages crawled: 314
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sk#mw-head. Number of Pages crawled: 315
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sk#searchInput. Number of Pages crawled: 316
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sv. Number of Pages crawled: 317
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sv#mw-head. Number of Pages crawled: 318
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/sv#searchInput. Number of Pages crawled: 319
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/uk. Number of Pages crawled: 320
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/uk#mw-head. Number of Pages crawled: 321
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/uk#searchInput. Number of Pages crawled: 322
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hans. Number of Pages crawled: 323
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hans#mw-head. Number of Pages crawled: 324
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hans#searchInput. Number of Pages crawled: 325
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hant. Number of Pages crawled: 326
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hant#mw-head. Number of Pages crawled: 327
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zh-hant#searchInput. Number of Pages crawled: 328
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zu. Number of Pages crawled: 329
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zu#mw-head. Number of Pages crawled: 330
# Crawled https://donate.wikimedia.org/wiki/Ways_to_Give/zu#searchInput. Number of Pages crawled: 331
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Ways_to_Give. Number of Pages crawled: 332
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Ways_to_Give#mw-head. Number of Pages crawled: 333
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=Ways_to_Give#searchInput. Number of Pages crawled: 334
# Crawled https://donate.wikimedia.org/wiki/Special:LandingCheck?landing_page=FAQ&basic=true&language=en. Number of Pages crawled: 335
# Crawled https://donate.wikimedia.org/w/index.php?title=FAQ/en&redirect=no. Number of Pages crawled: 336
# Crawled https://donate.wikimedia.org/w/index.php?title=FAQ/en&redirect=no#mw-head. Number of Pages crawled: 337
# Crawled https://donate.wikimedia.org/w/index.php?title=FAQ/en&redirect=no#searchInput. Number of Pages crawled: 338
# Crawled https://donate.wikimedia.org/wiki/FAQ. Number of Pages crawled: 339
# Crawled https://donate.wikimedia.org/wiki/FAQ#mw-head. Number of Pages crawled: 340
# Crawled https://donate.wikimedia.org/wiki/FAQ#searchInput. Number of Pages crawled: 341
# Crawled https://donate.wikimedia.org/wiki/FAQ/af. Number of Pages crawled: 342
# Crawled https://donate.wikimedia.org/wiki/FAQ/af#mw-head. Number of Pages crawled: 343
# Crawled https://donate.wikimedia.org/wiki/FAQ/af#searchInput. Number of Pages crawled: 344
# Crawled https://donate.wikimedia.org/wiki/FAQ/ar. Number of Pages crawled: 345
# Crawled https://donate.wikimedia.org/wiki/FAQ/ar#mw-head. Number of Pages crawled: 346
# Crawled https://donate.wikimedia.org/wiki/FAQ/ar#searchInput. Number of Pages crawled: 347
# Crawled https://donate.wikimedia.org/wiki/FAQ/ca. Number of Pages crawled: 348
# Crawled https://donate.wikimedia.org/wiki/FAQ/ca#mw-head. Number of Pages crawled: 349
# Crawled https://donate.wikimedia.org/wiki/FAQ/ca#searchInput. Number of Pages crawled: 350
# Crawled https://donate.wikimedia.org/wiki/FAQ/cs. Number of Pages crawled: 351
# Crawled https://donate.wikimedia.org/wiki/FAQ/cs#mw-head. Number of Pages crawled: 352
# Crawled https://donate.wikimedia.org/wiki/FAQ/cs#searchInput. Number of Pages crawled: 353
# Crawled https://donate.wikimedia.org/wiki/FAQ/da. Number of Pages crawled: 354
# Crawled https://donate.wikimedia.org/wiki/FAQ/da#mw-head. Number of Pages crawled: 355
# Crawled https://donate.wikimedia.org/wiki/FAQ/da#searchInput. Number of Pages crawled: 356
# Crawled https://donate.wikimedia.org/wiki/FAQ/de. Number of Pages crawled: 357
# Crawled https://donate.wikimedia.org/wiki/FAQ/de#mw-head. Number of Pages crawled: 358
# Crawled https://donate.wikimedia.org/wiki/FAQ/de#searchInput. Number of Pages crawled: 359
# Crawled https://donate.wikimedia.org/wiki/FAQ/el. Number of Pages crawled: 360
# Crawled https://donate.wikimedia.org/wiki/FAQ/el#mw-head. Number of Pages crawled: 361
# Crawled https://donate.wikimedia.org/wiki/FAQ/el#searchInput. Number of Pages crawled: 362
# Crawled https://donate.wikimedia.org/wiki/FAQ/es. Number of Pages crawled: 363
# Crawled https://donate.wikimedia.org/wiki/FAQ/es#mw-head. Number of Pages crawled: 364
# Crawled https://donate.wikimedia.org/wiki/FAQ/es#searchInput. Number of Pages crawled: 365
# Crawled https://donate.wikimedia.org/wiki/FAQ/fr. Number of Pages crawled: 366
# Crawled https://donate.wikimedia.org/wiki/FAQ/fr#mw-head. Number of Pages crawled: 367
# Crawled https://donate.wikimedia.org/wiki/FAQ/fr#searchInput. Number of Pages crawled: 368
# Crawled https://donate.wikimedia.org/wiki/FAQ/he. Number of Pages crawled: 369
# Crawled https://donate.wikimedia.org/wiki/FAQ/he#mw-head. Number of Pages crawled: 370
# Crawled https://donate.wikimedia.org/wiki/FAQ/he#searchInput. Number of Pages crawled: 371
# Crawled https://donate.wikimedia.org/wiki/FAQ/hu. Number of Pages crawled: 372
# Crawled https://donate.wikimedia.org/wiki/FAQ/hu#mw-head. Number of Pages crawled: 373
# Crawled https://donate.wikimedia.org/wiki/FAQ/hu#searchInput. Number of Pages crawled: 374
# Crawled https://donate.wikimedia.org/wiki/FAQ/it. Number of Pages crawled: 375
# Crawled https://donate.wikimedia.org/wiki/FAQ/it#mw-head. Number of Pages crawled: 376
# Crawled https://donate.wikimedia.org/wiki/FAQ/it#searchInput. Number of Pages crawled: 377
# Crawled https://donate.wikimedia.org/wiki/FAQ/ja. Number of Pages crawled: 378
# Crawled https://donate.wikimedia.org/wiki/FAQ/ja#mw-head. Number of Pages crawled: 379
# Crawled https://donate.wikimedia.org/wiki/FAQ/ja#searchInput. Number of Pages crawled: 380
# Crawled https://donate.wikimedia.org/wiki/FAQ/lv. Number of Pages crawled: 381
# Crawled https://donate.wikimedia.org/wiki/FAQ/lv#mw-head. Number of Pages crawled: 382
# Crawled https://donate.wikimedia.org/wiki/FAQ/lv#searchInput. Number of Pages crawled: 383
# Crawled https://donate.wikimedia.org/wiki/FAQ/nb. Number of Pages crawled: 384
# Crawled https://donate.wikimedia.org/wiki/FAQ/nb#mw-head. Number of Pages crawled: 385
# Crawled https://donate.wikimedia.org/wiki/FAQ/nb#searchInput. Number of Pages crawled: 386
# Crawled https://donate.wikimedia.org/wiki/FAQ/nl. Number of Pages crawled: 387
# Crawled https://donate.wikimedia.org/wiki/FAQ/nl#mw-head. Number of Pages crawled: 388
# Crawled https://donate.wikimedia.org/wiki/FAQ/nl#searchInput. Number of Pages crawled: 389
# Crawled https://donate.wikimedia.org/wiki/FAQ/pl. Number of Pages crawled: 390
# Crawled https://donate.wikimedia.org/wiki/FAQ/pl#mw-head. Number of Pages crawled: 391
# Crawled https://donate.wikimedia.org/wiki/FAQ/pl#searchInput. Number of Pages crawled: 392
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt. Number of Pages crawled: 393
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt#mw-head. Number of Pages crawled: 394
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt#searchInput. Number of Pages crawled: 395
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt-br. Number of Pages crawled: 396
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt-br#mw-head. Number of Pages crawled: 397
# Crawled https://donate.wikimedia.org/wiki/FAQ/pt-br#searchInput. Number of Pages crawled: 398
# Crawled https://donate.wikimedia.org/wiki/FAQ/ro. Number of Pages crawled: 399
# Crawled https://donate.wikimedia.org/wiki/FAQ/ro#mw-head. Number of Pages crawled: 400
# Crawled https://donate.wikimedia.org/wiki/FAQ/ro#searchInput. Number of Pages crawled: 401
# Crawled https://donate.wikimedia.org/wiki/FAQ/ru. Number of Pages crawled: 402
# Crawled https://donate.wikimedia.org/wiki/FAQ/ru#mw-head. Number of Pages crawled: 403
# Crawled https://donate.wikimedia.org/wiki/FAQ/ru#searchInput. Number of Pages crawled: 404
# Crawled https://donate.wikimedia.org/wiki/FAQ/sk. Number of Pages crawled: 405
# Crawled https://donate.wikimedia.org/wiki/FAQ/sk#mw-head. Number of Pages crawled: 406
# Crawled https://donate.wikimedia.org/wiki/FAQ/sk#searchInput. Number of Pages crawled: 407
# Crawled https://donate.wikimedia.org/wiki/FAQ/sv. Number of Pages crawled: 408
# Crawled https://donate.wikimedia.org/wiki/FAQ/sv#mw-head. Number of Pages crawled: 409
# Crawled https://donate.wikimedia.org/wiki/FAQ/sv#searchInput. Number of Pages crawled: 410
# Crawled https://donate.wikimedia.org/wiki/FAQ/uk. Number of Pages crawled: 411
# Crawled https://donate.wikimedia.org/wiki/FAQ/uk#mw-head. Number of Pages crawled: 412
# Crawled https://donate.wikimedia.org/wiki/FAQ/uk#searchInput. Number of Pages crawled: 413
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hans. Number of Pages crawled: 414
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hans#mw-head. Number of Pages crawled: 415
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hans#searchInput. Number of Pages crawled: 416
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hant. Number of Pages crawled: 417
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hant#mw-head. Number of Pages crawled: 418
# Crawled https://donate.wikimedia.org/wiki/FAQ/zh-hant#searchInput. Number of Pages crawled: 419
# Crawled https://donate.wikimedia.org/wiki/FAQ/zu. Number of Pages crawled: 420
# Crawled https://donate.wikimedia.org/wiki/FAQ/zu#mw-head. Number of Pages crawled: 421
# Crawled https://donate.wikimedia.org/wiki/FAQ/zu#searchInput. Number of Pages crawled: 422
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=FAQ. Number of Pages crawled: 423
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=FAQ#mw-head. Number of Pages crawled: 424
# Crawled https://donate.wikimedia.org/?uselang=zu&utm_medium=donatewiki_page&utm_campaign=donate_now_btn&utm_source=FAQ#searchInput. Number of Pages crawled: 425
# Crawled https://donate.wikimedia.org/wiki/Special:LandingPage. Number of Pages crawled: 426
# Crawled https://donate.wikimedia.org/wiki/Special:LandingPage#mw-head. Number of Pages crawled: 427
# Crawled https://donate.wikimedia.org/wiki/Special:LandingPage#searchInput. Number of Pages crawled: 428
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&returnto=Special%3ALandingPage. Number of Pages crawled: 429
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&returnto=Special%3ALandingPage#mw-head. Number of Pages crawled: 430
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&returnto=Special%3ALandingPage#searchInput. Number of Pages crawled: 431
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=de&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 432
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=de&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 433
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=de&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 434
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=en&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 435
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=en&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 436
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=en&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 437
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=eo&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 438
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=eo&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 439
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=eo&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 440
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=fr&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 441
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=fr&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 442
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=fr&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 443
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=es&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 444
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=es&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 445
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=es&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 446
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=it&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 447
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=it&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 448
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=it&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 449
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=nl&returnto=Special%3ALandingPage&returntoquery=. Number of Pages crawled: 450
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=nl&returnto=Special%3ALandingPage&returntoquery=#mw-head. Number of Pages crawled: 451
# Crawled https://donate.wikimedia.org/w/index.php?title=Special:UserLogin&uselang=nl&returnto=Special%3ALandingPage&returntoquery=#searchInput. Number of Pages crawled: 452
# Crawled https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Logging_in. Number of Pages crawled: 453
# Crawled https://www.mediawiki.org/wiki/Special:MyLanguage/Help:Logging_in#bodyContent. Number of Pages crawled: 454
# Crawled https://www.mediawiki.org/wiki/MediaWiki. Number of Pages crawled: 455
# Crawled https://www.mediawiki.org/wiki/MediaWiki#bodyContent. Number of Pages crawled: 456
# Crawled https://www.mediawiki.org/wiki/Download. Number of Pages crawled: 457
# Crawled https://www.mediawiki.org/wiki/Download#bodyContent. Number of Pages crawled: 458
# Crawled https://www.mediawiki.org/wiki/Special:MyLanguage/Category:Extensions. Number of Pages crawled: 459
# Crawled https://www.mediawiki.org/wiki/Special:MyLanguage/Category:Extensions#bodyContent. Number of Pages crawled: 460
# Crawled https://techblog.wikimedia.org/. Number of Pages crawled: 461
# Crawled https://techblog.wikimedia.org/#site-navigation. Number of Pages crawled: 462
# Crawled https://techblog.wikimedia.org/#content. Number of Pages crawled: 463
# Crawled https://techblog.wikimedia.org/#colophon. Number of Pages crawled: 464
# Crawled https://techblog.wikimedia.org/about/. Number of Pages crawled: 465
# Crawled https://techblog.wikimedia.org/about/#site-navigation. Number of Pages crawled: 466
# Crawled https://techblog.wikimedia.org/about/#content. Number of Pages crawled: 467
# Crawled https://techblog.wikimedia.org/about/#colophon. Number of Pages crawled: 468
# Crawled https://techblog.wikimedia.org/further-reading/. Number of Pages crawled: 469
# Crawled https://techblog.wikimedia.org/further-reading/#site-navigation. Number of Pages crawled: 470
# Crawled https://techblog.wikimedia.org/further-reading/#content. Number of Pages crawled: 471
# ...
# Crawled https://docs.github.com/en/get-started/using-git/dealing-with-special-characters-in-branch-and-tag-names. Number of Pages crawled: 886
# Crawled https://docs.github.com/en/get-started/using-git/dealing-with-special-characters-in-branch-and-tag-names#main-content. Number of Pages crawled: 887
# Crawled https://docs.github.com/en/get-started/using-git/troubleshooting-the-2-gb-push-limit. Number of Pages crawled: 888
# Crawled https://docs.github.com/en/get-started/using-git/troubleshooting-the-2-gb-push-limit#main-content. Number of Pages crawled: 889
# Crawled https://docs.github.com/en/get-started/exploring-integrations/about-using-integrations. Number of Pages crawled: 890
# Crawled https://docs.github.com/en/get-started/exploring-integrations/about-using-integrations#main-content. Number of Pages crawled: 891
# Crawled https://docs.github.com/en/get-started/exploring-integrations. Number of Pages crawled: 892
# Crawled https://docs.github.com/en/get-started/exploring-integrations#main-content. Number of Pages crawled: 893
# Crawled https://docs.github.com/en/get-started/exploring-integrations/about-building-integrations. Number of Pages crawled: 894
# Crawled https://docs.github.com/en/get-started/exploring-integrations/about-building-integrations#main-content. Number of Pages crawled: 895
# Crawled https://docs.github.com/en/get-started/exploring-integrations/featured-github-integrations. Number of Pages crawled: 896
# Crawled https://docs.github.com/en/get-started/exploring-integrations/featured-github-integrations#main-content. Number of Pages crawled: 897
# Crawled https://docs.github.com/en/get-started/exploring-integrations/github-developer-program. Number of Pages crawled: 898
# Crawled https://docs.github.com/en/get-started/exploring-integrations/github-developer-program#main-content. Number of Pages crawled: 899
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories/requesting-an-archive-of-your-personal-accounts-data. Number of Pages crawled: 900
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories/requesting-an-archive-of-your-personal-accounts-data#main-content. Number of Pages crawled: 901
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories. Number of Pages crawled: 902
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories#main-content. Number of Pages crawled: 903
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories/opting-into-or-out-of-the-github-archive-program-for-your-public-repository. Number of Pages crawled: 904
# Crawled https://docs.github.com/en/get-started/archiving-your-github-personal-account-and-public-repositories/opting-into-or-out-of-the-github-archive-program-for-your-public-repository#main-content. Number of Pages crawled: 905
# Crawled https://docs.github.com/en/get-started/using-github-docs/about-versions-of-github-docs. Number of Pages crawled: 906
# Crawled https://docs.github.com/en/get-started/using-github-docs/about-versions-of-github-docs#main-content. Number of Pages crawled: 907
# Crawled https://docs.github.com/en/get-started/using-github-docs. Number of Pages crawled: 908
# Crawled https://docs.github.com/en/get-started/using-github-docs#main-content. Number of Pages crawled: 909
# Crawled https://docs.github.com/en/get-started/using-github-docs/using-hover-cards-on-github-docs. Number of Pages crawled: 910
# Crawled https://docs.github.com/en/get-started/using-github-docs/using-hover-cards-on-github-docs#main-content. Number of Pages crawled: 911
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/about-github-certifications. Number of Pages crawled: 912
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/about-github-certifications#main-content. Number of Pages crawled: 913
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications. Number of Pages crawled: 914
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications#main-content. Number of Pages crawled: 915
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/registering-for-a-github-certifications-exam. Number of Pages crawled: 916
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/registering-for-a-github-certifications-exam#main-content. Number of Pages crawled: 917
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/registering-for-a-github-certifications-exam#about-registration. Number of Pages crawled: 918
# Crawled https://docs.github.com/en/get-started/showcase-your-expertise-with-github-certifications/registering-for-a-github-certifications-exam#about-identification-requirements. Number of Pages crawled: 919
# Error crawling https://examregistration.github.com/overview: 'NoneType' object has no attribute 'strip'
# Error crawling https://examregistration.github.com/: 'NoneType' object has no attribute 'strip'
# Error crawling https://examregistration.github.com/dashboard: 'NoneType' object has no attribute 'strip'
# Crawled https://examregistration.github.com/loginRedirect. Number of Pages crawled: 920
# Crawled https://examregistration.github.com/loginRedirect#start-of-content. Number of Pages crawled: 921
# Crawled https://docs.github.com/site-policy/privacy-policies/github-privacy-statement. Number of Pages crawled: 922
# Crawled https://docs.github.com/site-policy/privacy-policies/github-privacy-statement#main-content. Number of Pages crawled: 923
# Crawled https://docs.github.com/en/site-policy. Number of Pages crawled: 924
# Crawled https://docs.github.com/en/site-policy#main-content. Number of Pages crawled: 925
# Crawled https://docs.github.com/en/site-policy/github-terms/github-terms-of-service. Number of Pages crawled: 926
# Crawled https://docs.github.com/en/site-policy/github-terms/github-terms-of-service#main-content. Number of Pages crawled: 927
# Crawled https://docs.github.com/en/site-policy/github-terms. Number of Pages crawled: 928
# Crawled https://docs.github.com/en/site-policy/github-terms#main-content. Number of Pages crawled: 929
# Crawled https://docs.github.com/en/site-policy/github-terms/github-corporate-terms-of-service. Number of Pages crawled: 930
# Crawled https://docs.github.com/en/site-policy/github-terms/github-corporate-terms-of-service#main-content. Number of Pages crawled: 931
# Crawled https://docs.github.com/en/site-policy/github-terms/github-terms-for-additional-products-and-features. Number of Pages crawled: 932
# Crawled https://docs.github.com/en/site-policy/github-terms/github-terms-for-additional-products-and-features#main-content. Number of Pages crawled: 933
# Crawled https://docs.github.com/en/site-policy/github-terms/github-community-guidelines. Number of Pages crawled: 934
# Crawled https://docs.github.com/en/site-policy/github-terms/github-community-guidelines#main-content. Number of Pages crawled: 935
# Crawled https://docs.github.com/en/site-policy/github-terms/github-community-code-of-conduct. Number of Pages crawled: 936
# Crawled https://docs.github.com/en/site-policy/github-terms/github-community-code-of-conduct#main-content. Number of Pages crawled: 937
# Crawled https://docs.github.com/en/site-policy/github-terms/github-pre-release-license-terms. Number of Pages crawled: 938
# Crawled https://docs.github.com/en/site-policy/github-terms/github-pre-release-license-terms#main-content. Number of Pages crawled: 939
# Crawled https://docs.github.com/en/site-policy/github-terms/github-sponsors-additional-terms. Number of Pages crawled: 940
# Crawled https://docs.github.com/en/site-policy/github-terms/github-sponsors-additional-terms#main-content. Number of Pages crawled: 941
# Crawled https://docs.github.com/en/site-policy/github-terms/github-registered-developer-agreement. Number of Pages crawled: 942
# Crawled https://docs.github.com/en/site-policy/github-terms/github-registered-developer-agreement#main-content. Number of Pages crawled: 943
# Crawled https://docs.github.com/en/site-policy/github-terms/github-marketplace-terms-of-service. Number of Pages crawled: 944
# Crawled https://docs.github.com/en/site-policy/github-terms/github-marketplace-terms-of-service#main-content. Number of Pages crawled: 945
# Crawled https://docs.github.com/en/site-policy/github-terms/github-marketplace-developer-agreement. Number of Pages crawled: 946
# Crawled https://docs.github.com/en/site-policy/github-terms/github-marketplace-developer-agreement#main-content. Number of Pages crawled: 947
# Crawled https://docs.github.com/en/site-policy/github-terms/github-research-program-terms. Number of Pages crawled: 948
# Crawled https://docs.github.com/en/site-policy/github-terms/github-research-program-terms#main-content. Number of Pages crawled: 949
# Crawled https://docs.github.com/en/site-policy/github-terms/github-open-source-applications-terms-and-conditions. Number of Pages crawled: 950
# Crawled https://docs.github.com/en/site-policy/github-terms/github-open-source-applications-terms-and-conditions#main-content. Number of Pages crawled: 951
# Crawled https://docs.github.com/en/site-policy/github-terms/github-event-terms. Number of Pages crawled: 952
# Crawled https://docs.github.com/en/site-policy/github-terms/github-event-terms#main-content. Number of Pages crawled: 953
# Crawled https://docs.github.com/en/site-policy/github-terms/github-event-code-of-conduct. Number of Pages crawled: 954
# Crawled https://docs.github.com/en/site-policy/github-terms/github-event-code-of-conduct#main-content. Number of Pages crawled: 955
# Crawled https://docs.github.com/en/site-policy/github-terms/github-educational-use-agreement. Number of Pages crawled: 956
# Crawled https://docs.github.com/en/site-policy/github-terms/github-educational-use-agreement#main-content. Number of Pages crawled: 957
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-acceptable-use-policies. Number of Pages crawled: 958
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-acceptable-use-policies#main-content. Number of Pages crawled: 959
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies. Number of Pages crawled: 960
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies#main-content. Number of Pages crawled: 961
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-active-malware-or-exploits. Number of Pages crawled: 962
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-active-malware-or-exploits#main-content. Number of Pages crawled: 963
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-bullying-and-harassment. Number of Pages crawled: 964
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-bullying-and-harassment#main-content. Number of Pages crawled: 965
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-disrupting-the-experience-of-other-users. Number of Pages crawled: 966
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-disrupting-the-experience-of-other-users#main-content. Number of Pages crawled: 967
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-doxxing-and-invasion-of-privacy. Number of Pages crawled: 968
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-doxxing-and-invasion-of-privacy#main-content. Number of Pages crawled: 969
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-hate-speech-and-discrimination. Number of Pages crawled: 970
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-hate-speech-and-discrimination#main-content. Number of Pages crawled: 971
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-impersonation. Number of Pages crawled: 972
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-impersonation#main-content. Number of Pages crawled: 973
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-misinformation-and-disinformation. Number of Pages crawled: 974
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-misinformation-and-disinformation#main-content. Number of Pages crawled: 975
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-sexually-obscene-content. Number of Pages crawled: 976
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-sexually-obscene-content#main-content. Number of Pages crawled: 977
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-threats-of-violence-and-gratuitously-violent-content. Number of Pages crawled: 978
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-threats-of-violence-and-gratuitously-violent-content#main-content. Number of Pages crawled: 979
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-appeal-and-reinstatement. Number of Pages crawled: 980
# Crawled https://docs.github.com/en/site-policy/acceptable-use-policies/github-appeal-and-reinstatement#main-content. Number of Pages crawled: 981
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-general-privacy-statement. Number of Pages crawled: 982
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-general-privacy-statement#main-content. Number of Pages crawled: 983
# Crawled https://docs.github.com/en/site-policy/privacy-policies. Number of Pages crawled: 984
# Crawled https://docs.github.com/en/site-policy/privacy-policies#main-content. Number of Pages crawled: 985
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-subprocessors. Number of Pages crawled: 986
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-subprocessors#main-content. Number of Pages crawled: 987
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-cookies. Number of Pages crawled: 988
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-cookies#main-content. Number of Pages crawled: 989
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-codespaces-privacy-statement. Number of Pages crawled: 990
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-codespaces-privacy-statement#main-content. Number of Pages crawled: 991
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-candidate-privacy-policy. Number of Pages crawled: 992
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-candidate-privacy-policy#main-content. Number of Pages crawled: 993
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-octernships-terms-of-service. Number of Pages crawled: 994
# Crawled https://docs.github.com/en/site-policy/privacy-policies/github-octernships-terms-of-service#main-content. Number of Pages crawled: 995
# Crawled https://docs.github.com/en/site-policy/other-site-policies/github-and-trade-controls. Number of Pages crawled: 996
# Crawled https://docs.github.com/en/site-policy/other-site-policies/github-and-trade-controls#main-content. Number of Pages crawled: 997
# Crawled https://docs.github.com/en/site-policy/other-site-policies. Number of Pages crawled: 998
# Crawled https://docs.github.com/en/site-policy/other-site-policies#main-content. Number of Pages crawled: 999
# Crawled https://docs.github.com/en/site-policy/other-site-policies/github-deceased-user-policy. Number of Pages crawled: 1000
# Root directory for crawled pages: C:\Users\USER\Desktop\Amna Sameer Assignment 2\crawled_pages
